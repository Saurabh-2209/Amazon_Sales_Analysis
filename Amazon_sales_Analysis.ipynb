# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Amazon Sale Report.csv")

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
df['fulfilled-by'].value_counts()
# Out:
# fulfilled-by
# Easy Ship    39263
# Name: count, dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
df.columns = df.columns.str.replace(" ","_")

# %%
df.columns = df.columns.str.replace("-","_")

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['index', 'order_id', 'date', 'status', 'fulfilment', 'sales_channel',
#        'ship_service_level', 'category', 'size', 'courier_status', 'qty',
#        'currency', 'amount', 'ship_city', 'ship_state', 'ship_postal_code',
#        'ship_country', 'b2b', 'fulfilled_by', 'new', 'pendings'],
#       dtype='object')

# %%
df.fulfilled_by.fillna("others",inplace=True)

# %%
df.fulfilled_by.value_counts()
# Out:
# fulfilled_by
# others       89713
# Easy Ship    39263
# Name: count, dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# index                   0.000000
# order_id                0.000000
# date                    0.000000
# status                  0.000000
# fulfilment              0.000000
# sales_channel           0.000000
# ship_service_level      0.000000
# category                0.000000
# size                    0.000000
# courier_status          0.000000
# qty                     0.000000
# currency                6.047637
# amount                  6.047637
# ship_city               0.027137
# ship_state              0.027137
# ship_postal_code        0.027137
# ship_country            0.027137
# b2b                     0.000000
# fulfilled_by            0.000000
# new                   100.000000
# pendings              100.000000
# dtype: float64

# %%
df.currency.value_counts()
# Out:
# currency
# INR    121176
# Name: count, dtype: int64

# %%
df.currency.fillna("INR", inplace=True)

# %%
(df.isnull().sum()/len(df))*100
# Out:
# index                   0.000000
# order_id                0.000000
# date                    0.000000
# status                  0.000000
# fulfilment              0.000000
# sales_channel           0.000000
# ship_service_level      0.000000
# category                0.000000
# size                    0.000000
# courier_status          0.000000
# qty                     0.000000
# currency                0.000000
# amount                  6.047637
# ship_city               0.027137
# ship_state              0.027137
# ship_postal_code        0.027137
# ship_country            0.027137
# b2b                     0.000000
# fulfilled_by            0.000000
# new                   100.000000
# pendings              100.000000
# dtype: float64

# %%
df.shape
# Out:
# (128976, 21)

# %%
df.drop(columns=["new","pendings"],inplace=True)

# %%
df.shape
# Out:
# (128976, 19)

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (121143, 19)

# %%
(df.isnull().sum()/len(df))*100
# Out:
# index                 0.0
# order_id              0.0
# date                  0.0
# status                0.0
# fulfilment            0.0
# sales_channel         0.0
# ship_service_level    0.0
# category              0.0
# size                  0.0
# courier_status        0.0
# qty                   0.0
# currency              0.0
# amount                0.0
# ship_city             0.0
# ship_state            0.0
# ship_postal_code      0.0
# ship_country          0.0
# b2b                   0.0
# fulfilled_by          0.0
# dtype: float64

# %%
df.head()
# Out:
#    index             order_id      date                        status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   fulfilment sales_channel ship_service_level  category size courier_status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    qty currency  amount    ship_city   ship_state  ship_postal_code  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 121143 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               121143 non-null  int64
#  1   order_id            121143 non-null  object
#  2   date                121143 non-null  object
#  3   status              121143 non-null  object
#  4   fulfilment          121143 non-null  object
#  5   sales_channel       121143 non-null  object
#  6   ship_service_level  121143 non-null  object
#  7   category            121143 non-null  object
#  8   size                121143 non-null  object
#  9   courier_status      121143 non-null  object
#  10  qty                 121143 non-null  int64
#  11  currency            121143 non-null  object
#  12  amount              121143 non-null  float64
#  13  ship_city           121143 non-null  object
#  14  ship_state          121143 non-null  object
# ...

# %%
df.date = pd.to_datetime(df.date)
df.ship_postal_code = df.ship_postal_code.astype("int64")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 121143 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               121143 non-null  int64
#  1   order_id            121143 non-null  object
#  2   date                121143 non-null  datetime64[ns]
#  3   status              121143 non-null  object
#  4   fulfilment          121143 non-null  object
#  5   sales_channel       121143 non-null  object
#  6   ship_service_level  121143 non-null  object
#  7   category            121143 non-null  object
#  8   size                121143 non-null  object
#  9   courier_status      121143 non-null  object
#  10  qty                 121143 non-null  int64
#  11  currency            121143 non-null  object
#  12  amount              121143 non-null  float64
#  13  ship_city           121143 non-null  object
#  14  ship_state          121143 non-null  object
# ...

# %%
df["month"] = df.date.dt.month_name()

# %%
df["year"] = df.date.dt.year

# %%
df.head()
# Out:
#    index             order_id       date                        status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   fulfilment sales_channel ship_service_level  category size courier_status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  amount    ship_city   ship_state ship_postal_code  \
# ...

# %%
df["day"] = df.date.dt.day_name()

# %%
df.head()
# Out:
#    index             order_id       date                        status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   fulfilment sales_channel ship_service_level  category size courier_status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  amount    ship_city   ship_state ship_postal_code ship_country    b2b  \
# ...

# %%
df.year.value_counts()
# Out:
# year
# 2022    121143
# Name: count, dtype: int64

# %%
df.month.value_counts()
# Out:
# month
# April    46049
# May      39525
# June     35407
# March      162
# Name: count, dtype: int64

# %%
df.day.value_counts()
# Out:
# day
# Sunday       18495
# Tuesday      17699
# Saturday     17457
# Monday       17448
# Wednesday    17425
# Friday       16579
# Thursday     16040
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                index                           date            qty  \
# count  121143.000000                         121143  121143.000000
# mean    64486.312655  2022-05-12 12:11:22.182214144       0.961252
# min         0.000000            2022-03-31 00:00:00       0.000000
# 25%     32294.500000            2022-04-20 00:00:00       1.000000
# 50%     64477.000000            2022-05-10 00:00:00       1.000000
# 75%     96682.500000            2022-06-04 00:00:00       1.000000
# max    128974.000000            2022-06-29 00:00:00       8.000000
# std     37220.415404                            NaN       0.214276
#
#               amount  ship_postal_code      year
# count  121143.000000     121143.000000  121143.0
# mean      648.576874     463623.724507    2022.0
# min         0.000000     110001.000000    2022.0
# 25%       449.000000     382421.000000    2022.0
# 50%       605.000000     500032.000000    2022.0
# 75%       788.000000     600020.000000    2022.0
# ...

# %%
df.head()
# Out:
#    index             order_id       date                        status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   fulfilment sales_channel ship_service_level  category size courier_status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  amount    ship_city   ship_state ship_postal_code ship_country    b2b  \
# ...

# %%
columns  = ["status","fulfilment","sales_channel","ship_service_level","category","size","courier_status","ship_city","ship_state"]
for i in columns:
    print(df[i].value_counts())
    print("-------------------------------")
# Out:
# status
# Shipped                          77589
# Shipped - Delivered to Buyer     28741
# Cancelled                        10758
# Shipped - Returned to Seller      1948
# Shipped - Picked Up                973
# Pending                            656
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64
# -------------------------------
# fulfilment
# Amazon      83629
# Merchant    37514
# Name: count, dtype: int64
# -------------------------------
# sales_channel
# Amazon.in    121143
# Name: count, dtype: int64
# -------------------------------
# ship_service_level
# Expedited    82713
# Standard     38430
# Name: count, dtype: int64
# -------------------------------
# category
# T-shirt     47038
# Shirt       46695
# Blazzer     14702
# Trousers    10157
# ...

# %%
df[df.ship_city == 'BENGALURU']
# Out:
#          index             order_id       date                        status  \
# 1            1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 19          19  405-5957858-1051546 2022-04-30                       Shipped
# 21          21  404-8494550-5860325 2022-04-30                       Shipped
# 28          28  405-7755803-4729935 2022-04-30                       Shipped
# 53          53  402-1752649-2274748 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# 128853  128852  404-7444867-4101107 2022-06-01                       Shipped
# 128913  128912  408-2355947-8808311 2022-05-31                       Shipped
# 128940  128939  407-9521244-5120341 2022-05-31                       Shipped
# 128942  128941  403-3035549-4142738 2022-05-31                       Shipped
# 128943  128942  403-3035549-4142738 2022-05-31                       Shipped
#
# ...

# %%
categories = pd.DataFrame(df.category.value_counts())
categories.head()
# Out:
#           count
# category
# T-shirt   47038
# Shirt     46695
# Blazzer   14702
# Trousers  10157
# Perfume    1091

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
plt.pie(df.courier_status.value_counts(),autopct="%0.2f%%", labels=df.courier_status.value_counts().keys())
plt.title("Courier Status")

plt.subplot(2,2,2)
ax= sns.countplot(x= "size", data =df)
ax.bar_label(ax.containers[0])
plt.title("Size")

plt.subplot(2,2,3)

plt.tight_layout()
ax = sns.barplot(x = categories.index, y = "count",data =categories)
plt.xticks(rotation= 45)
ax.bar_label(ax.containers[0])

plt.subplot(2,2,4)
ax = sns.countplot(x  ='status', data = df )
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 90)
plt.show()

# %%
df.to_csv("Amazon_sales_cleaned.csv")

# %%
df = pd.read_csv("Amazon_sales_cleaned.csv")
import pymysql
from sqlalchemy import create_engine

import urllib.parse

password = urllib.parse.quote_plus('Saurabh@2001')
engine_mysql = create_engine(f"mysql+pymysql://root:{password}@localhost:3306/Amazon_sales")
try:
    engine_mysql
    print("Connection Successful")
except:
    print("Failed To connect")

df.to_sql(name='sales', con=engine_mysql, if_exists='append', index=False)
# Out:
# Connection Successful
# 121143

# %%
ship_state = df.ship_state.value_counts()

# %%
ship_state
# Out:
# ship_state
# MAHARASHTRA               21084
# KARNATAKA                 16390
# TAMIL NADU                10813
# TELANGANA                 10636
# UTTAR PRADESH              9956
#                           ...
# Mizoram                       1
# rajsthan                      1
# Punjab/Mohali/Zirakpur        1
# Rajsthan                      1
# PB                            1
# Name: count, Length: 68, dtype: int64

# %% [markdown]
# ### inconsistent ship states names
# - rajshthan,rj,rajsthan => rajasthan
# - orissa => odisha
# - puducherry  => pondicherry
# - ar => arunachal pradesh
# - pj => punjab
# - nl => nagaland

# %%
df.ship_state = df.ship_state.str.lower()

# %%
df.ship_state = df.ship_state.str.strip()

# %%
df.ship_state = df.ship_state.apply(lambda x : "rajasthan" if x in ["rajshthan","rj","rajsthan"] else "odisha" if x == "orissa" else "pondicherry" if x == "puducherry" else "arunachal pradesh" if x == "ar" else "punjab" if x == "pb" else "nagaland" if x == "nl" else x)

# %%
df.ship_state.value_counts()
# Out:
# ship_state
# maharashtra               21084
# karnataka                 16390
# tamil nadu                10813
# telangana                 10636
# uttar pradesh              9956
# delhi                      6564
# kerala                     6143
# west bengal                5546
# andhra pradesh             5052
# haryana                    4184
# gujarat                    4146
# rajasthan                  2536
# madhya pradesh             2370
# odisha                     1998
# bihar                      1962
# punjab                     1806
# assam                      1549
# uttarakhand                1444
# jharkhand                  1353
# goa                        1081
# chhattisgarh                864
# himachal pradesh            725
# jammu & kashmir             650
# pondicherry                 324
# chandigarh                  319
# manipur                     299
# andaman & nicobar           242
# meghalaya                   197
# sikkim                      190
# ...

# %%
import pymysql
from sqlalchemy import create_engine

import urllib.parse

password = urllib.parse.quote_plus('Saurabh@2001')
engine_mysql = create_engine(f"mysql+pymysql://root:{password}@localhost:3306/Amazon_sales")
try:
    engine_mysql
    print("Connection Successful")
except:
    print("Failed To connect")

df.to_sql(name='sales', con=engine_mysql, if_exists='append', index=False)
# Out:
# Connection Successful
# 121143

# %%
df.ship_state.value_counts()
# Out:
# ship_state
# maharashtra               21084
# karnataka                 16390
# tamil nadu                10813
# telangana                 10636
# uttar pradesh              9956
# delhi                      6564
# kerala                     6143
# west bengal                5546
# andhra pradesh             5052
# haryana                    4184
# gujarat                    4146
# rajasthan                  2536
# madhya pradesh             2370
# odisha                     1998
# bihar                      1962
# punjab                     1806
# assam                      1549
# uttarakhand                1444
# jharkhand                  1353
# goa                        1081
# chhattisgarh                864
# himachal pradesh            725
# jammu & kashmir             650
# pondicherry                 324
# chandigarh                  319
# manipur                     299
# andaman & nicobar           242
# meghalaya                   197
# sikkim                      190
# ...

# %%
city_wise_sales = pd.DataFrame(df.groupby(["ship_state",'ship_city'])['amount'].sum())

# %%
df.month.value_counts()
# Out:
# month
# April    46049
# May      39525
# June     35407
# March      162
# Name: count, dtype: int64

# %%
city_wise_sales
# Out:
#                                                            amount
# ship_state        ship_city
# andaman & nicobar Andaman and nicobar islands port Blair   999.00
#                   BAMBOOFLAT                              7208.24
#                   FERRARGUNJ                              5714.00
#                   GARACHARMA                               307.00
#                   GREAT NICOBAR                           1973.00
# ...                                                           ...
# west bengal       salt lake city                           499.00
#                   siliguri                                1036.00
#                   tufanganj                               1194.00
#                   uluberia, howrah                         301.00
#                   west bengal                              335.00
#
# [8789 rows x 1 columns]
